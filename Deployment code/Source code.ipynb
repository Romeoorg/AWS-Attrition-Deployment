# %%
#import the packages or libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import seaborn as sns
pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings('ignore')

# %%
#loading the data from the datasets
df=pd.read_csv('train.csv')
df.head(10)
# Out:
#    Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0         8410   31    Male                19   Education            5390
# 1        64756   59  Female                 4       Media            5534
# 2        30257   24  Female                10  Healthcare            8159
# 3        65791   36  Female                 7   Education            3989
# 4        65026   56    Male                41   Education            4821
# 5        24368   38  Female                 3  Technology            9977
# 6        64970   47    Male                23   Education            3681
# 7        36999   48    Male                16     Finance           11223
# 8        32714   57    Male                44   Education            3773
# 9        15944   24  Female                 1  Healthcare            7319
#
#   Work-Life Balance Job Satisfaction Performance Rating  Number of Promotions  \
# 0         Excellent           Medium            Average                     2
# 1              Poor             High                Low                     3
# 2              Good             High                Low                     0
# 3              Good             High               High                     1
# 4              Fair        Very High            Average                     0
# 5              Fair             High      Below Average                     3
# 6              Fair             High               High                     1
# 7         Excellent        Very High               High                     2
# 8              Good           Medium               High                     1
# 9              Poor             High            Average                     1
#
#   Overtime  Distance from Home    Education Level Marital Status  \
# 0       No                  22   Associate Degree        Married
# 1       No                  21    Master’s Degree       Divorced
# 2       No                  11  Bachelor’s Degree        Married
# 3       No                  27        High School         Single
# 4      Yes                  71        High School       Divorced
# 5       No                  37  Bachelor’s Degree        Married
# 6      Yes                  75        High School       Divorced
# 7       No                   5    Master’s Degree        Married
# 8      Yes                  39        High School        Married
# 9      Yes                  57                PhD         Single
#
#    Number of Dependents Job Level Company Size  Company Tenure Remote Work  \
# 0                     0       Mid       Medium              89          No
# 1                     3       Mid       Medium              21          No
# 2                     3       Mid       Medium              74          No
# 3                     2       Mid        Small              50         Yes
# 4                     0    Senior       Medium              68          No
# 5                     0       Mid       Medium              47          No
# 6                     3     Entry        Small              93          No
# 7                     4     Entry       Medium              88          No
# 8                     4     Entry       Medium              75          No
# 9                     4     Entry        Large              45          No
#
#   Leadership Opportunities Innovation Opportunities Company Reputation  \
# 0                       No                       No          Excellent
# 1                       No                       No               Fair
# 2                       No                       No               Poor
# 3                       No                       No               Good
# 4                       No                       No               Fair
# 5                       No                      Yes               Fair
# 6                       No                       No               Good
# 7                       No                       No          Excellent
# 8                       No                       No               Fair
# 9                       No                      Yes               Good
#
#   Employee Recognition Attrition
# 0               Medium    Stayed
# 1                  Low    Stayed
# 2                  Low    Stayed
# 3               Medium    Stayed
# 4               Medium    Stayed
# 5                 High      Left
# 6               Medium      Left
# 7                  Low    Stayed
# 8               Medium    Stayed
# 9                  Low      Left

# %%
#EDA
#Exploratory Data Analysis
#view the statistics of the datasets
df.describe()
# Out:
#         Employee ID          Age  Years at Company  Monthly Income  \
# count   8186.000000  8186.000000       8186.000000     8186.000000
# mean   37287.220743    38.615075         15.667237     7336.613609
# std    21446.665299    12.135169         11.291536     2141.167892
# min        8.000000    18.000000          1.000000     1855.000000
# 25%    18757.250000    28.000000          7.000000     5714.000000
# 50%    37088.500000    39.000000         13.000000     7373.000000
# 75%    55937.750000    49.000000         23.000000     8879.500000
# max    74488.000000    59.000000         51.000000    15495.000000
#
#        Number of Promotions  Distance from Home  Number of Dependents  \
# count           8186.000000         8186.000000           8186.000000
# mean               0.827144           49.724408              1.649890
# std                0.996414           28.518282              1.556062
# min                0.000000            1.000000              0.000000
# 25%                0.000000           25.000000              0.000000
# 50%                0.000000           50.000000              1.000000
# 75%                1.000000           74.000000              3.000000
# max                4.000000           99.000000              6.000000
#
#        Company Tenure
# count     8186.000000
# mean        55.863059
# std         25.546607
# min          2.000000
# 25%         36.000000
# 50%         56.000000
# 75%         76.000000
# max        127.000000

# %%
df.head()
# Out:
#    Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0         8410   31    Male                19   Education            5390
# 1        64756   59  Female                 4       Media            5534
# 2        30257   24  Female                10  Healthcare            8159
# 3        65791   36  Female                 7   Education            3989
# 4        65026   56    Male                41   Education            4821
#
#   Work-Life Balance Job Satisfaction Performance Rating  Number of Promotions  \
# 0         Excellent           Medium            Average                     2
# 1              Poor             High                Low                     3
# 2              Good             High                Low                     0
# 3              Good             High               High                     1
# 4              Fair        Very High            Average                     0
#
#   Overtime  Distance from Home    Education Level Marital Status  \
# 0       No                  22   Associate Degree        Married
# 1       No                  21    Master’s Degree       Divorced
# 2       No                  11  Bachelor’s Degree        Married
# 3       No                  27        High School         Single
# 4      Yes                  71        High School       Divorced
#
#    Number of Dependents Job Level Company Size  Company Tenure Remote Work  \
# 0                     0       Mid       Medium              89          No
# 1                     3       Mid       Medium              21          No
# 2                     3       Mid       Medium              74          No
# 3                     2       Mid        Small              50         Yes
# 4                     0    Senior       Medium              68          No
#
#   Leadership Opportunities Innovation Opportunities Company Reputation  \
# 0                       No                       No          Excellent
# 1                       No                       No               Fair
# 2                       No                       No               Poor
# 3                       No                       No               Good
# 4                       No                       No               Fair
#
#   Employee Recognition Attrition
# 0               Medium    Stayed
# 1                  Low    Stayed
# 2                  Low    Stayed
# 3               Medium    Stayed
# 4               Medium    Stayed

# %%
df.isnull().values
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ...,  True,  True,  True]])

# %%
#check for any missing /null values in the data
df.isnull().values.any()
# Out:
# True

# %%
#Get the information about the datasets
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8186 entries, 0 to 8185
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Employee ID               8186 non-null   int64
#  1   Age                       8186 non-null   int64
#  2   Gender                    8186 non-null   object
#  3   Years at Company          8186 non-null   int64
#  4   Job Role                  8186 non-null   object
#  5   Monthly Income            8186 non-null   int64
#  6   Work-Life Balance         8186 non-null   object
#  7   Job Satisfaction          8186 non-null   object
#  8   Performance Rating        8186 non-null   object
#  9   Number of Promotions      8186 non-null   int64
#  10  Overtime                  8186 non-null   object
#  11  Distance from Home        8186 non-null   int64
#  12  Education Level           8186 non-null   object
#  13  Marital Status            8186 non-null   object
#  14  Number of Dependents      8186 non-null   int64
#  15  Job Level                 8186 non-null   object
#  16  Company Size              8186 non-null   object
#  17  Company Tenure            8186 non-null   int64
#  18  Remote Work               8186 non-null   object
#  19  Leadership Opportunities  8186 non-null   object
#  20  Innovation Opportunities  8186 non-null   object
#  21  Company Reputation        8185 non-null   object
#  22  Employee Recognition      8185 non-null   object
#  23  Attrition                 8185 non-null   object
# dtypes: int64(8), object(16)
# memory usage: 1.5+ MB

# %%
#Get the count of the number of Employee that stayed or left the company
df['Attrition'].value_counts()
# Out:
# Attrition
# Stayed    4282
# Left      3903
# Name: count, dtype: int64

# %%
#Get all the data types and their unique values
for column in df.columns:
    if df[column].dtype == object:
        print(str(column)+ ' : '+ str(df[column].unique()))
        print(df[column].value_counts())
        print('_________________')
# Out:
# Gender : ['Male' 'Female']
# Gender
# Male      4500
# Female    3686
# Name: count, dtype: int64
# _________________
# Job Role : ['Education' 'Media' 'Healthcare' 'Technology' 'Finance']
# Job Role
# Technology    2201
# Healthcare    1852
# Education     1638
# Media         1322
# Finance       1173
# Name: count, dtype: int64
# _________________
# Work-Life Balance : ['Excellent' 'Poor' 'Good' 'Fair']
# Work-Life Balance
# Good         3089
# Fair         2525
# Excellent    1436
# Poor         1136
# Name: count, dtype: int64
# _________________
# Job Satisfaction : ['Medium' 'High' 'Very High' 'Low']
# Job Satisfaction
# High         4100
# Very High    1647
# Medium       1612
# Low           827
# Name: count, dtype: int64
# _________________
# Performance Rating : ['Average' 'Low' 'High' 'Below Average']
# Performance Rating
# Average          4974
# High             1619
# Below Average    1196
# Low               397
# Name: count, dtype: int64
# _________________
# Overtime : ['No' 'Yes']
# Overtime
# No     5554
# Yes    2632
# Name: count, dtype: int64
# _________________
# Education Level : ['Associate Degree' 'Master’s Degree' 'Bachelor’s Degree' 'High School'
#  'PhD']
# Education Level
# Bachelor’s Degree    2406
# Associate Degree     2043
# Master’s Degree      1679
# High School          1604
# PhD                   454
# Name: count, dtype: int64
# _________________
# Marital Status : ['Married' 'Divorced' 'Single']
# Marital Status
# Married     4101
# Single      2848
# Divorced    1237
# Name: count, dtype: int64
# _________________
# Job Level : ['Mid' 'Senior' 'Entry']
# Job Level
# Mid       3346
# Entry     3213
# Senior    1627
# Name: count, dtype: int64
# _________________
# Company Size : ['Medium' 'Small' 'Large']
# Company Size
# Medium    4104
# Small     2443
# Large     1639
# Name: count, dtype: int64
# _________________
# Remote Work : ['No' 'Yes']
# Remote Work
# No     6607
# Yes    1579
# Name: count, dtype: int64
# _________________
# Leadership Opportunities : ['No' 'Yes']
# Leadership Opportunities
# No     7799
# Yes     387
# Name: count, dtype: int64
# _________________
# Innovation Opportunities : ['No' 'Yes']
# Innovation Opportunities
# No     6874
# Yes    1312
# Name: count, dtype: int64
# _________________
# Company Reputation : ['Excellent' 'Fair' 'Poor' 'Good' nan]
# Company Reputation
# Good         4036
# Poor         1667
# Fair         1655
# Excellent     827
# Name: count, dtype: int64
# _________________
# Employee Recognition : ['Medium' 'Low' 'High' 'Very High' nan]
# Employee Recognition
# Low          3267
# Medium       2439
# High         2062
# Very High     417
# Name: count, dtype: int64
# _________________
# Attrition : ['Stayed' 'Left' nan]
# Attrition
# Stayed    4282
# Left      3903
# Name: count, dtype: int64
# _________________

# %%
#lets convert this attrition to label
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Attrition']= le.fit_transform(df['Attrition'])
df.head(20)
# Out:
#     Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0          8410   31    Male                19   Education            5390
# 1         64756   59  Female                 4       Media            5534
# 2         30257   24  Female                10  Healthcare            8159
# 3         65791   36  Female                 7   Education            3989
# 4         65026   56    Male                41   Education            4821
# 5         24368   38  Female                 3  Technology            9977
# 6         64970   47    Male                23   Education            3681
# 7         36999   48    Male                16     Finance           11223
# 8         32714   57    Male                44   Education            3773
# 9         15944   24  Female                 1  Healthcare            7319
# 10        29972   30  Female                12   Education            5443
# 11         9063   29  Female                 6  Healthcare            8950
# 12        21896   47  Female                38  Technology            9039
# 13        28098   31    Male                22  Healthcare            8090
# 14        22068   40  Female                30  Technology            6350
# 15        17696   40  Female                 4     Finance            5176
# 16        55668   19  Female                 9  Technology            8242
# 17        19288   33  Female                 1     Finance            8733
# 18        17034   49  Female                37       Media            6252
# 19         9697   29    Male                 9  Healthcare            7538
#
#    Work-Life Balance Job Satisfaction Performance Rating  \
# 0          Excellent           Medium            Average
# 1               Poor             High                Low
# 2               Good             High                Low
# 3               Good             High               High
# 4               Fair        Very High            Average
# 5               Fair             High      Below Average
# 6               Fair             High               High
# 7          Excellent        Very High               High
# 8               Good           Medium               High
# 9               Poor             High            Average
# 10              Good             High            Average
# 11              Poor           Medium                Low
# 12              Fair        Very High               High
# 13              Fair           Medium               High
# 14              Good             High            Average
# 15              Poor             High            Average
# 16         Excellent           Medium            Average
# 17              Good             High      Below Average
# 18              Fair             High               High
# 19              Fair           Medium            Average
#
#     Number of Promotions Overtime  Distance from Home    Education Level  \
# 0                      2       No                  22   Associate Degree
# 1                      3       No                  21    Master’s Degree
# 2                      0       No                  11  Bachelor’s Degree
# 3                      1       No                  27        High School
# 4                      0      Yes                  71        High School
# 5                      3       No                  37  Bachelor’s Degree
# 6                      1      Yes                  75        High School
# 7                      2       No                   5    Master’s Degree
# 8                      1      Yes                  39        High School
# 9                      1      Yes                  57                PhD
# 10                     1       No                  51        High School
# 11                     2       No                  26    Master’s Degree
# 12                     1       No                  78   Associate Degree
# 13                     4      Yes                  30   Associate Degree
# 14                     0       No                  98        High School
# 15                     0       No                  48        High School
# 16                     2      Yes                  17        High School
# 17                     1      Yes                  86        High School
# 18                     2       No                  60  Bachelor’s Degree
# 19                     0       No                  10  Bachelor’s Degree
#
#    Marital Status  Number of Dependents Job Level Company Size  \
# 0         Married                     0       Mid       Medium
# 1        Divorced                     3       Mid       Medium
# 2         Married                     3       Mid       Medium
# 3          Single                     2       Mid        Small
# 4        Divorced                     0    Senior       Medium
# 5         Married                     0       Mid       Medium
# 6        Divorced                     3     Entry        Small
# 7         Married                     4     Entry       Medium
# 8         Married                     4     Entry       Medium
# 9          Single                     4     Entry        Large
# 10         Single                     1     Entry        Small
# 11         Single                     0       Mid       Medium
# 12        Married                     0     Entry        Small
# 13       Divorced                     2       Mid        Small
# 14         Single                     0    Senior        Large
# 15         Single                     0     Entry        Small
# 16         Single                     3       Mid        Small
# 17         Single                     0       Mid        Small
# 18       Divorced                     4    Senior       Medium
# 19        Married                     0    Senior        Small
#
#     Company Tenure Remote Work Leadership Opportunities  \
# 0               89          No                       No
# 1               21          No                       No
# 2               74          No                       No
# 3               50         Yes                       No
# 4               68          No                       No
# 5               47          No                       No
# 6               93          No                       No
# 7               88          No                       No
# 8               75          No                       No
# 9               45          No                       No
# 10              17          No                       No
# 11              38          No                       No
# 12              68          No                       No
# 13              84          No                       No
# 14              96          No                       No
# 15              21         Yes                       No
# 16              63          No                       No
# 17              19          No                       No
# 18              70          No                       No
# 19              76          No                       No
#
#    Innovation Opportunities Company Reputation Employee Recognition  Attrition
# 0                        No          Excellent               Medium          1
# 1                        No               Fair                  Low          1
# 2                        No               Poor                  Low          1
# 3                        No               Good               Medium          1
# 4                        No               Fair               Medium          1
# 5                       Yes               Fair                 High          0
# 6                        No               Good               Medium          0
# 7                        No          Excellent                  Low          1
# 8                        No               Fair               Medium          1
# 9                       Yes               Good                  Low          0
# 10                       No               Good               Medium          0
# 11                       No               Poor               Medium          0
# 12                       No               Good                  Low          0
# 13                       No               Good               Medium          1
# 14                       No               Good                 High          1
# 15                       No               Good                 High          0
# 16                       No               Fair                 High          0
# 17                       No               Good                  Low          1
# 18                       No               Good                 High          1
# 19                       No               Good                 High          1

# %%
stayed = df.Attrition == 0
left = df.Attrition == 1

# %%
plt.hist(df[stayed].Age, alpha=0.5, label='stayed')
plt.title('Age')
plt.xlabel ('Age')
plt.ylabel('Samples')
plt.legend()
plt.show()

# %%
plt.hist(df[left].Age, alpha = 0.5, label = 'left')
plt.title('Age')
plt.xlabel('Age')
plt.ylabel('Samples')
plt.legend()
plt.show()

# %%
le.classes_
# Out:
# array(['Left', 'Stayed', nan], dtype=object)

# %%
#Attrition = {#tayed: 0, left : 1}

# %%
Attrition_Employee = le.classes_
print(Attrition_Employee)
# Out:
# ['Left' 'Stayed' nan]

# %%
#ploting the distribution
p = df.hist(figsize = (20,20))

# %%
#check the balance of the data by plotting the count of Attrition
Color_wheel = {1: "0392cf", 2: "#7bc043"}
Colors = df["Attrition"].map(lambda x: Color_wheel.get(x+1))
print(df.Attrition.value_counts())
p =df.Attrition.value_counts().plot(kind= "bar")
# Out:
# Attrition
# 1    4282
# 0    3903
# 2       1
# Name: count, dtype: int64

# %%
#Define the columns to be laebl encoded
labels_cols = ['Gender','Job Role','Overtime','Education Level','Marital Status','Company Size','Remote Work',
              'Leadership Opportunities', 'Innovation Opportunities','Work-Life Balance', 'Job Satisfaction','Performance Rating',
              'Company Reputation','Job Level', 'Employee Recognition']

#initialize label encoders
label_encoders = {col: LabelEncoder() for col in labels_cols}

#Apply the label Encoding
for col in labels_cols:
    df[col] = label_encoders[col].fit_transform(df[col])

# %%
df.head(10)
# Out:
#    Employee ID  Age  Gender  Years at Company  Job Role  Monthly Income  \
# 0         8410   31       1                19         0            5390
# 1        64756   59       0                 4         3            5534
# 2        30257   24       0                10         2            8159
# 3        65791   36       0                 7         0            3989
# 4        65026   56       1                41         0            4821
# 5        24368   38       0                 3         4            9977
# 6        64970   47       1                23         0            3681
# 7        36999   48       1                16         1           11223
# 8        32714   57       1                44         0            3773
# 9        15944   24       0                 1         2            7319
#
#    Work-Life Balance  Job Satisfaction  Performance Rating  \
# 0                  0                 2                   0
# 1                  3                 0                   3
# 2                  2                 0                   3
# 3                  2                 0                   2
# 4                  1                 3                   0
# 5                  1                 0                   1
# 6                  1                 0                   2
# 7                  0                 3                   2
# 8                  2                 2                   2
# 9                  3                 0                   0
#
#    Number of Promotions  Overtime  Distance from Home  Education Level  \
# 0                     2         0                  22                0
# 1                     3         0                  21                3
# 2                     0         0                  11                1
# 3                     1         0                  27                2
# 4                     0         1                  71                2
# 5                     3         0                  37                1
# 6                     1         1                  75                2
# 7                     2         0                   5                3
# 8                     1         1                  39                2
# 9                     1         1                  57                4
#
#    Marital Status  Number of Dependents  Job Level  Company Size  \
# 0               1                     0          1             1
# 1               0                     3          1             1
# 2               1                     3          1             1
# 3               2                     2          1             2
# 4               0                     0          2             1
# 5               1                     0          1             1
# 6               0                     3          0             2
# 7               1                     4          0             1
# 8               1                     4          0             1
# 9               2                     4          0             0
#
#    Company Tenure  Remote Work  Leadership Opportunities  \
# 0              89            0                         0
# 1              21            0                         0
# 2              74            0                         0
# 3              50            1                         0
# 4              68            0                         0
# 5              47            0                         0
# 6              93            0                         0
# 7              88            0                         0
# 8              75            0                         0
# 9              45            0                         0
#
#    Innovation Opportunities  Company Reputation  Employee Recognition  \
# 0                         0                   0                     2
# 1                         0                   1                     1
# 2                         0                   3                     1
# 3                         0                   2                     2
# 4                         0                   1                     2
# 5                         1                   1                     0
# 6                         0                   2                     2
# 7                         0                   0                     1
# 8                         0                   1                     2
# 9                         1                   2                     1
#
#    Attrition
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# 5          0
# 6          0
# 7          1
# 8          1
# 9          0

# %%
x=df.iloc[:, :-1]
#remove the last column Attrition

# %%
x.head()
# Out:
#    Employee ID  Age  Gender  Years at Company  Job Role  Monthly Income  \
# 0         8410   31       1                19         0            5390
# 1        64756   59       0                 4         3            5534
# 2        30257   24       0                10         2            8159
# 3        65791   36       0                 7         0            3989
# 4        65026   56       1                41         0            4821
#
#    Work-Life Balance  Job Satisfaction  Performance Rating  \
# 0                  0                 2                   0
# 1                  3                 0                   3
# 2                  2                 0                   3
# 3                  2                 0                   2
# 4                  1                 3                   0
#
#    Number of Promotions  Overtime  Distance from Home  Education Level  \
# 0                     2         0                  22                0
# 1                     3         0                  21                3
# 2                     0         0                  11                1
# 3                     1         0                  27                2
# 4                     0         1                  71                2
#
#    Marital Status  Number of Dependents  Job Level  Company Size  \
# 0               1                     0          1             1
# 1               0                     3          1             1
# 2               1                     3          1             1
# 3               2                     2          1             2
# 4               0                     0          2             1
#
#    Company Tenure  Remote Work  Leadership Opportunities  \
# 0              89            0                         0
# 1              21            0                         0
# 2              74            0                         0
# 3              50            1                         0
# 4              68            0                         0
#
#    Innovation Opportunities  Company Reputation  Employee Recognition
# 0                         0                   0                     2
# 1                         0                   1                     1
# 2                         0                   3                     1
# 3                         0                   2                     2
# 4                         0                   1                     2

# %%
#Remove the total column Attrition

# %%
y = df.iloc[:, -1]

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Attrition, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_Train, X_Test, Y_Train, Y_Test = train_test_split(x,y, test_size = 0.3)

# %%
trainDF = X_Train.join(Y_Train)

# %%
X_Train.head(5)
# Out:
#       Employee ID  Age  Gender  Years at Company  Job Role  Monthly Income  \
# 3217        58071   47       0                29         3            5244
# 3185        10410   23       1                11         4           10868
# 1746        21457   54       1                33         4            9980
# 3774        32285   25       0                 9         1            7836
# 3466        29109   52       1                38         4            9711
#
#       Work-Life Balance  Job Satisfaction  Performance Rating  \
# 3217                  1                 2                   0
# 3185                  1                 3                   1
# 1746                  2                 1                   0
# 3774                  2                 0                   0
# 3466                  3                 0                   0
#
#       Number of Promotions  Overtime  Distance from Home  Education Level  \
# 3217                     2         1                  59                4
# 3185                     4         0                  49                3
# 1746                     3         0                   4                3
# 3774                     0         0                   2                3
# 3466                     0         0                  45                2
#
#       Marital Status  Number of Dependents  Job Level  Company Size  \
# 3217               1                     1          1             0
# 3185               2                     1          1             2
# 1746               0                     4          0             1
# 3774               2                     3          0             1
# 3466               1                     0          0             2
#
#       Company Tenure  Remote Work  Leadership Opportunities  \
# 3217              74            0                         0
# 3185              70            0                         0
# 1746             109            0                         0
# 3774              22            0                         0
# 3466              45            0                         0
#
#       Innovation Opportunities  Company Reputation  Employee Recognition
# 3217                         0                   0                     1
# 3185                         0                   3                     1
# 1746                         0                   3                     2
# 3774                         0                   2                     0
# 3466                         0                   2                     2

# %%
trainDF=X_Train.join(Y_Train)
trainDF.head(5)
# Out:
#       Employee ID  Age  Gender  Years at Company  Job Role  Monthly Income  \
# 3217        58071   47       0                29         3            5244
# 3185        10410   23       1                11         4           10868
# 1746        21457   54       1                33         4            9980
# 3774        32285   25       0                 9         1            7836
# 3466        29109   52       1                38         4            9711
#
#       Work-Life Balance  Job Satisfaction  Performance Rating  \
# 3217                  1                 2                   0
# 3185                  1                 3                   1
# 1746                  2                 1                   0
# 3774                  2                 0                   0
# 3466                  3                 0                   0
#
#       Number of Promotions  Overtime  Distance from Home  Education Level  \
# 3217                     2         1                  59                4
# 3185                     4         0                  49                3
# 1746                     3         0                   4                3
# 3774                     0         0                   2                3
# 3466                     0         0                  45                2
#
#       Marital Status  Number of Dependents  Job Level  Company Size  \
# 3217               1                     1          1             0
# 3185               2                     1          1             2
# 1746               0                     4          0             1
# 3774               2                     3          0             1
# 3466               1                     0          0             2
#
#       Company Tenure  Remote Work  Leadership Opportunities  \
# 3217              74            0                         0
# 3185              70            0                         0
# 1746             109            0                         0
# 3774              22            0                         0
# 3466              45            0                         0
#
#       Innovation Opportunities  Company Reputation  Employee Recognition  \
# 3217                         0                   0                     1
# 3185                         0                   3                     1
# 1746                         0                   3                     2
# 3774                         0                   2                     0
# 3466                         0                   2                     2
#
#       Attrition
# 3217          0
# 3185          1
# 1746          1
# 3774          0
# 3466          0

# %%
testDF = X_Test.join(Y_Test)
testDF.head(5)
# Out:
#       Employee ID  Age  Gender  Years at Company  Job Role  Monthly Income  \
# 447         58212   31       0                11         2            8320
# 4526        40419   34       0                21         4            9832
# 4731         4394   32       1                23         3            6302
# 6078         4580   37       0                 4         2            8131
# 7776        71243   36       0                19         2            7908
#
#       Work-Life Balance  Job Satisfaction  Performance Rating  \
# 447                   2                 0                   1
# 4526                  3                 1                   1
# 4731                  0                 0                   0
# 6078                  0                 0                   0
# 7776                  1                 0                   0
#
#       Number of Promotions  Overtime  Distance from Home  Education Level  \
# 447                      0         1                   8                4
# 4526                     2         0                  49                1
# 4731                     2         0                   2                1
# 6078                     0         1                  77                0
# 7776                     2         1                  14                2
#
#       Marital Status  Number of Dependents  Job Level  Company Size  \
# 447                1                     6          0             1
# 4526               1                     1          1             1
# 4731               2                     0          0             0
# 6078               2                     0          1             1
# 7776               0                     1          1             1
#
#       Company Tenure  Remote Work  Leadership Opportunities  \
# 447               61            1                         0
# 4526              83            0                         0
# 4731              62            1                         1
# 6078              32            0                         0
# 7776              64            1                         0
#
#       Innovation Opportunities  Company Reputation  Employee Recognition  \
# 447                          0                   2                     3
# 4526                         0                   1                     1
# 4731                         0                   1                     2
# 6078                         0                   0                     1
# 7776                         0                   2                     1
#
#       Attrition
# 447           1
# 4526          0
# 4731          1
# 6078          0
# 7776          1

# %%
column = ['Attrition',
          'Age','Gender',
          'Years at Company',
          'Job Role','Marital Status',
          'Education Level',
          'Job Level',
          'Number of Dependents',
          'Monthly Income',
          'Work-Life Balance',
          'Job Satisfaction','Overtime',
          'Distance from Home','Company Size',
          'Company Tenure','Remote Work',
          'Leadership Opportunities',
          'Innovation Opportunities',
          'Company Reputation',
          'Employee Recognition',
         ]

# %%
trainDF= trainDF[column]
trainDF.head(10)
# Out:
#       Attrition  Age  Gender  Years at Company  Job Role  Marital Status  \
# 3217          0   47       0                29         3               1
# 3185          1   23       1                11         4               2
# 1746          1   54       1                33         4               0
# 3774          0   25       0                 9         1               2
# 3466          0   52       1                38         4               1
# 1065          0   57       1                 2         4               2
# 4889          0   59       1                 1         1               2
# 2964          0   39       1                11         3               1
# 7827          0   37       1                15         1               1
# 7114          1   50       1                39         4               1
#
#       Education Level  Job Level  Number of Dependents  Monthly Income  \
# 3217                4          1                     1            5244
# 3185                3          1                     1           10868
# 1746                3          0                     4            9980
# 3774                3          0                     3            7836
# 3466                2          0                     0            9711
# 1065                0          1                     2            8515
# 4889                0          1                     0            6513
# 2964                0          1                     0            7056
# 7827                1          0                     3            9354
# 7114                3          0                     1           12459
#
#       Work-Life Balance  Job Satisfaction  Overtime  Distance from Home  \
# 3217                  1                 2         1                  59
# 3185                  1                 3         0                  49
# 1746                  2                 1         0                   4
# 3774                  2                 0         0                   2
# 3466                  3                 0         0                  45
# 1065                  2                 2         0                  43
# 4889                  2                 2         1                  55
# 2964                  2                 2         1                  79
# 7827                  0                 0         0                  94
# 7114                  2                 0         0                  43
#
#       Company Size  Company Tenure  Remote Work  Leadership Opportunities  \
# 3217             0              74            0                         0
# 3185             2              70            0                         0
# 1746             1             109            0                         0
# 3774             1              22            0                         0
# 3466             2              45            0                         0
# 1065             1              70            0                         0
# 4889             1              28            0                         0
# 2964             2              15            0                         0
# 7827             2              92            0                         0
# 7114             2              90            0                         0
#
#       Innovation Opportunities  Company Reputation  Employee Recognition
# 3217                         0                   0                     1
# 3185                         0                   3                     1
# 1746                         0                   3                     2
# 3774                         0                   2                     0
# 3466                         0                   2                     2
# 1065                         1                   2                     0
# 4889                         0                   2                     0
# 2964                         1                   1                     1
# 7827                         1                   2                     1
# 7114                         0                   0                     0

# %%
testDF = testDF [column[1:]]
testDF.head()
# Out:
#       Age  Gender  Years at Company  Job Role  Marital Status  \
# 447    31       0                11         2               1
# 4526   34       0                21         4               1
# 4731   32       1                23         3               2
# 6078   37       0                 4         2               2
# 7776   36       0                19         2               0
#
#       Education Level  Job Level  Number of Dependents  Monthly Income  \
# 447                 4          0                     6            8320
# 4526                1          1                     1            9832
# 4731                1          0                     0            6302
# 6078                0          1                     0            8131
# 7776                2          1                     1            7908
#
#       Work-Life Balance  Job Satisfaction  Overtime  Distance from Home  \
# 447                   2                 0         1                   8
# 4526                  3                 1         0                  49
# 4731                  0                 0         0                   2
# 6078                  0                 0         1                  77
# 7776                  1                 0         1                  14
#
#       Company Size  Company Tenure  Remote Work  Leadership Opportunities  \
# 447              1              61            1                         0
# 4526             1              83            0                         0
# 4731             0              62            1                         1
# 6078             1              32            0                         0
# 7776             1              64            1                         0
#
#       Innovation Opportunities  Company Reputation  Employee Recognition
# 447                          0                   2                     3
# 4526                         0                   1                     1
# 4731                         0                   1                     2
# 6078                         0                   0                     1
# 7776                         0                   2                     1

# %%
#Save the trained data#
#write training set#

trainDF.to_csv('traineddataattritions.csv',index=False, index_label='Row',header=False, columns=column)

# %%
testDF.head()
# Out:
#       Age  Gender  Years at Company  Job Role  Marital Status  \
# 447    31       0                11         2               1
# 4526   34       0                21         4               1
# 4731   32       1                23         3               2
# 6078   37       0                 4         2               2
# 7776   36       0                19         2               0
#
#       Education Level  Job Level  Number of Dependents  Monthly Income  \
# 447                 4          0                     6            8320
# 4526                1          1                     1            9832
# 4731                1          0                     0            6302
# 6078                0          1                     0            8131
# 7776                2          1                     1            7908
#
#       Work-Life Balance  Job Satisfaction  Overtime  Distance from Home  \
# 447                   2                 0         1                   8
# 4526                  3                 1         0                  49
# 4731                  0                 0         0                   2
# 6078                  0                 0         1                  77
# 7776                  1                 0         1                  14
#
#       Company Size  Company Tenure  Remote Work  Leadership Opportunities  \
# 447              1              61            1                         0
# 4526             1              83            0                         0
# 4731             0              62            1                         1
# 6078             1              32            0                         0
# 7776             1              64            1                         0
#
#       Innovation Opportunities  Company Reputation  Employee Recognition
# 447                          0                   2                     3
# 4526                         0                   1                     1
# 4731                         0                   1                     2
# 6078                         0                   0                     1
# 7776                         0                   2                     1

# %%
trainDF.to_csv('testddataattritions.csv',index=False, index_label='Row',header=False, columns=column)

# %%
import boto3 #this package is to integrate with s3 bucket or other cloude service//
import re #this package is to folow a strict pattern to save your work/regular expresession//

# %%
#Specify bucket name
bucketNM='romeodiabetecbucket'
TrainFile = r'attritiondata/traineddataattritions/traineddataattritions.csv'
TestFile = r'attritiondata/testddataattritions/testddataattritions.csv'
ValFile = r'attritiondata/Val/Val.csv'
ModelFolder = r'attritiondata/model/'

# %%
#loading
s3ModelOutput=r's3://{0}/{1}'.format(bucketNM, ModelFolder)
s3Train=r's3://{0}/{1}'.format(bucketNM, TrainFile)
s3Test=r's3://{0}/{1}'.format(bucketNM, TestFile)
s3Val=r's3://{0}/{1}'.format(bucketNM, ValFile)

# %%
s3ModelOutput
# Out:
# 's3://romeodiabetecbucket/attritiondata/model/'

# %%
with open('traineddataattritions.csv','rb') as f:
    boto3.Session().resource('s3').Bucket(bucketNM).Object(TrainFile).upload_fileobj(f)

# %%
with open('testddataattritions.csv','rb') as f:
    boto3.Session().resource('s3').Bucket(bucketNM).Object(TestFile).upload_fileobj(f)

# %%
import sagemaker
from sagemaker import get_execution_role
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %%
sagemakerSess=sagemaker.Session()
role=get_execution_role()

# %%
sagemakerSess.boto_region_name
# Out:
# 'us-east-1'

# %%
ECRdockercontainer=sagemaker.amazon.amazon_estimator.get_image_uri(sagemakerSess.boto_region_name,'linear-learner','latest')
# Out:
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: latest.

# %%
LogisticModel=sagemaker.estimator.Estimator(image_uri=ECRdockercontainer,
                                           role=role,
                                            train_instance_count=1,
                                            train_instance_type='ml.m4.xlarge',
                                            output_path=s3ModelOutput,
                                            sagemaker_session=sagemakerSess,
                                            base_job_name = 'Logistic-Demo-v1'
                                           )
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
LogisticModel.set_hyperparameters(predictor_type='binary_classifier', mini_batch_size=100)

# %%
LogisticModel.hyperparameters()
# Out:
# {'predictor_type': 'binary_classifier', 'mini_batch_size': 100}

# %%
trainConfig=sagemaker.session.s3_input(s3_data=s3Train,content_type='text/csv')
# Out:
# The class sagemaker.session.s3_input has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
LogisticModel.fit({'train':trainConfig})
# Out:
# INFO:sagemaker:Creating training-job with name: Logistic-Demo-v1-2024-08-20-12-34-10-548
# 2024-08-20 12:34:10 Starting - Starting the training job...
# 2024-08-20 12:34:25 Starting - Preparing the instances for training...
# 2024-08-20 12:34:56 Downloading - Downloading input data...
# 2024-08-20 12:35:26 Downloading - Downloading the training image......
# 2024-08-20 12:36:37 Training - Training image download completed. Training in progress....Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [08/20/2024 12:37:01 INFO 139985293625152] Reading default configuration from /opt/amazon/lib/python3.8/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [08/20/2024 12:37:01 INFO 139985293625152] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'mini_batch_size': '100', 'predictor_type': 'binary_classifier'}
# [08/20/2024 12:37:01 INFO 139985293625152] Final configuration: {'mini_batch_size': '100', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# /opt/amazon/lib/python3.8/site-packages/mxnet/model.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num_device is 1 and 'dist' not in kvstore:
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:495: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if cons['type'] is 'ineq':
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:743: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if len(self.X_min) is not 0:
#
, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6931327685975192, "count": 1, "min": 0.6931327685975192, "max": 0.6931327685975192}}}
# #metrics {"StartTime": 1724157426.275951, "EndTime": 1724157426.2759597, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6918384511847245, "count": 1, "min": 0.6918384511847245, "max": 0.6918384511847245}}}
# #metrics {"StartTime": 1724157426.2759907, "EndTime": 1724157426.2759998, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6918408243279708, "count": 1, "min": 0.6918408243279708, "max": 0.6918408243279708}}}
# #metrics {"StartTime": 1724157426.2760293, "EndTime": 1724157426.2760375, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.708879822848136, "count": 1, "min": 0.708879822848136, "max": 0.708879822848136}}}
# #metrics {"StartTime": 1724157426.276067, "EndTime": 1724157426.2760768, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7093808398330421, "count": 1, "min": 0.7093808398330421, "max": 0.7093808398330421}}}
# #metrics {"StartTime": 1724157426.2761023, "EndTime": 1724157426.276112, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7080772868373938, "count": 1, "min": 0.7080772868373938, "max": 0.7080772868373938}}}
# #metrics {"StartTime": 1724157426.2761605, "EndTime": 1724157426.2761712, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7089131579482765, "count": 1, "min": 0.7089131579482765, "max": 0.7089131579482765}}}
# [08/20/2024 12:37:06 INFO 139985293625152] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy_objective <loss>=0.6406231328060753
# [08/20/2024 12:37:06 INFO 139985293625152] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_cross_entropy_objective, value=0.5935180670754951
# [08/20/2024 12:37:06 INFO 139985293625152] Epoch 0: Loss improved. Updating best model
# [08/20/2024 12:37:06 INFO 139985293625152] Saving model for epoch: 0
# [08/20/2024 12:37:06 INFO 139985293625152] Saved checkpoint to "/tmp/tmpbl3ym4l7/mx-mod-0000.params"
# [08/20/2024 12:37:06 INFO 139985293625152] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1724157424.9651127, "EndTime": 1724157426.2843015, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 11560.0, "count": 1, "min": 11560, "max": 11560}, "Total Batches Seen": {"sum": 117.0, "count": 1, "min": 117, "max": 117}, "Max Records Seen Between Resets": {"sum": 5730.0, "count": 1, "min": 5730, "max": 5730}, "Max Batches Seen Between Resets": {"sum": 58.0, "count": 1, "min": 58, "max": 58}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 5730.0, "count": 1, "min": 5730, "max": 5730}, "Number of Batches Since Last Reset": {"sum": 58.0, "count": 1, "min": 58, "max": 58}}}
# [08/20/2024 12:37:06 INFO 139985293625152] #throughput_metric: host=algo-1, train throughput=4343.227432201457 records/second
# #metrics {"StartTime": 1724157427.9248843, "EndTime": 1724157427.9249792, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5814164185105709, "count": 1, "min": 0.5814164185105709, "max": 0.5814164185105709}}}
# #metrics {"StartTime": 1724157427.9250646, "EndTime": 1724157427.9250774, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5811746925220155, "count": 1, "min": 0.5811746925220155, "max": 0.5811746925220155}}}
# #metrics {"StartTime": 1724157427.9251142, "EndTime": 1724157427.9251232, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5737987197072882, "count": 1, "min": 0.5737987197072882, "max": 0.5737987197072882}}}
# #metrics {"StartTime": 1724157427.9251626, "EndTime": 1724157427.9251716, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5792957419679876, "count": 1, "min": 0.5792957419679876, "max": 0.5792957419679876}}}
# #metrics {"StartTime": 1724157427.92521, "EndTime": 1724157427.925219, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5812264091090152, "count": 1, "min": 0.5812264091090152, "max": 0.5812264091090152}}}
# #metrics {"StartTime": 1724157427.9252536, "EndTime": 1724157427.9252625, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5834878968355949, "count": 1, "min": 0.5834878968355949, "max": 0.5834878968355949}}}
# #metrics {"StartTime": 1724157427.9252932, "EndTime": 1724157427.925302, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.
, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6920369492915639, "count": 1, "min": 0.6920369492915639, "max": 0.6920369492915639}}}
# #metrics {"StartTime": 1724157427.9261215, "EndTime": 1724157427.9261298, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6919576330352247, "count": 1, "min": 0.6919576330352247, "max": 0.6919576330352247}}}
# #metrics {"StartTime": 1724157427.926163, "EndTime": 1724157427.9261713, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6919989174290707, "count": 1, "min": 0.6919989174290707, "max": 0.6919989174290707}}}
# #metrics {"StartTime": 1724157427.9262018, "EndTime": 1724157427.9262102, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6919805279112698, "count": 1, "min": 0.6919805279112698, "max": 0.6919805279112698}}}
# #metrics {"StartTime": 1724157427.9262416, "EndTime": 1724157427.9262505, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.699116315339741, "count": 1, "min": 0.699116315339741, "max": 0.699116315339741}}}
# #metrics {"StartTime": 1724157427.9262786, "EndTime": 1724157427.9262872, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.700247707701566, "count": 1, "min": 0.700247707701566, "max": 0.700247707701566}}}
# #metrics {"StartTime": 1724157427.926315, "EndTime": 1724157427.9263237, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6990164264879729, "count": 1, "min": 0.6990164264879729, "max": 0.6990164264879729}}}
# #metrics {"StartTime": 1724157427.9263527, "EndTime": 1724157427.9263616, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7006496161745306, "count": 1, "min": 0.7006496161745306, "max": 0.7006496161745306}}}
# [08/20/2024 12:37:07 INFO 139985293625152] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.5814164185105709
# [08/20/2024 12:37:07 INFO 139985293625152] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_cross_entropy_objective, value=0.5737987197072882
# [08/20/2024 12:37:07 INFO 139985293625152] Epoch 1: Loss improved. Updating best model
# [08/20/2024 12:37:07 INFO 139985293625152] Saving model for epoch: 1
# [08/20/2024 12:37:07 INFO 139985293625152] Saved checkpoint to "/tmp/tmp0rtljbpr/mx-mod-0000.params"
# [08/20/2024 12:37:07 INFO 139985293625152] #progress_metric: host=algo-1, completed 13.333333333333334 % of epochs
# #metrics {"StartTime": 1724157426.2844903, "EndTime": 1724157427.9644501, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 17290.0, "count": 1, "min": 17290, "max": 17290}, "Total Batches Seen": {"sum": 175.0, "count": 1, "min": 175, "max": 175}, "Max Records Seen Between Resets": {"sum": 5730.0, "count": 1, "min": 5730, "max": 5730}, "Max Batches Seen Between Resets": {"sum": 58.0, "count": 1, "min": 58, "max": 58}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 5730.0, "count": 1, "min": 5730, "max": 5730}, "Number of Batches Since Last Reset": {"sum": 58.0, "count": 1, "min": 58, "max": 58}}}
# [08/20/2024 12:37:07 INFO 139985293625152] #throughput_metric: host=algo-1, train throughput=3410.52877513157 records/second
# #metrics {"StartTime": 1724157429.3873959, "EndTime": 1724157429.387447, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5612831269649037, "count": 1, "min": 0.5612831269649037, "max": 0.5612831269649037}}}
# #metrics {"StartTime": 1724157429.387511, "EndTime": 1724157429.38752, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5603213574593527, "count": 1, "min": 0.5603213574593527, "max": 0.5603213574593527}}}
# #metrics {"StartTime": 1724157429.3875518, "EndTime": 1724157429.3875608, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5576991305434913, "count": 1, "min": 0.5576991305434913, "max": 0.5576991305434913}}}
# #metrics {"StartTime": 1724157429.3875902, "EndTime": 1724157429.3875988, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.559239985148112, "count": 1, "min": 0.559239985148112, "max": 0.559239985148112}}}
# #metrics {"StartTime": 1724157429.3876321, "EndTime": 1724157429.3876417, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5793034188789233, "count": 1, "min": 0.5793034188789233, "max": 0.5793034188789233}}}
# #metrics {"StartTime": 1724157429.3876793, "EndTime": 1724157429.3876896, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.
, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6919041121633429, "count": 1, "min": 0.6919041121633429, "max": 0.6919041121633429}}}
# #metrics {"StartTime": 1724157429.3885264, "EndTime": 1724157429.3885357, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.69191939370674, "count": 1, "min": 0.69191939370674, "max": 0.69191939370674}}}
# #metrics {"StartTime": 1724157429.38857, "EndTime": 1724157429.3885796, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6918978614137884, "count": 1, "min": 0.6918978614137884, "max": 0.6918978614137884}}}
# #metrics {"StartTime": 1724157429.3886013, "EndTime": 1724157429.3886096, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6919331185859546, "count": 1, "min": 0.6919331185859546, "max": 0.6919331185859546}}}
# #metrics {"StartTime": 1724157429.3886445, "EndTime": 1724157429.3886533, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6996444126597622, "count": 1, "min": 0.6996444126597622, "max": 0.6996444126597622}}}
# #metrics {"StartTime": 1724157429.3886883, "EndTime": 1724157429.3886976, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7019236219974986, "count": 1, "min": 0.7019236219974986, "max": 0.7019236219974986}}}
# #metrics {"StartTime": 1724157429.3887334, "EndTime": 1724157429.3887427, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.699653409991348, "count": 1, "min": 0.699653409991348, "max": 0.699653409991348}}}
# #metrics {"StartTime": 1724157429.3887794, "EndTime": 1724157429.3887885, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7020249283104613, "count": 1, "min": 0.7020249283104613, "max": 0.7020249283104613}}}
# [08/20/2024 12:37:09 INFO 139985293625152] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy_objective <loss>=0.5612831269649037
# [08/20/2024 12:37:09 INFO 139985293625152] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_cross_entropy_objective, value=0.5576991305434913
# [08/20/2024 12:37:09 INFO 139985293625152] Epoch 2: Loss improved. Updating best model
# [08/20/2024 12:37:09 INFO 139985293625152] Saving model for epoch: 2
# [08/20/2024 12:37:09 INFO 139985293625152] Saved checkpoint to "/tmp/tmp0c3s66fu/mx-mod-0000.params"
# [08/20/2024 12:37:09 INFO 139985293625152] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1724157427.9647315, "EndTime": 1724157429.3956447, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 23020.0, "count": 1, "min": 23020, "max": 23020}, "Total Batches Seen": {"sum": 233.0, "count": 1, "min": 233, "max": 233}, "Max Records Seen Between Resets": {"sum": 5730.0, "count": 1, "min": 5730, "max": 5730}, "Max Batches Seen Between Resets": {"sum": 58.0, "count": 1, "min": 58, "max": 58}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 5730.0, "count": 1, "min": 5730, "max": 5730}, "Number of Batches Since Last Reset": {"sum": 58.0, "count": 1, "min": 58, "max": 58}}}
# [08/20/2024 12:37:09 INFO 139985293625152] #throughput_metric: host=algo-1, train throughput=4004.07547534456 records/second
# #metrics {"StartTime": 1724157430.6969466, "EndTime": 1724157430.6969974, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5537002737480298, "count": 1, "min": 0.5537002737480298, "max": 0.5537002737480298}}}
# #metrics {"StartTime": 1724157430.6970632, "EndTime": 1724157430.697072, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.552942905760648, "count": 1, "min": 0.552942905760648, "max": 0.552942905760648}}}
# #metrics {"StartTime": 1724157430.697096, "EndTime": 1724157430.697105, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5520635819016841, "count": 1, "min": 0.5520635819016841, "max": 0.5520635819016841}}}
# #metrics {"StartTime": 1724157430.697139, "EndTime": 1724157430.6971476, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5523991320426004, "count": 1, "min": 0.5523991320426004, "max": 0.5523991320426004}}}
# ...
# #metrics {"StartTime": 1724157438.4288676, "EndTime": 1724157438.428875, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.
, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.659745540953519, "count": 1, "min": 0.659745540953519, "max": 0.659745540953519}}}
# #metrics {"StartTime": 1724157438.4296613, "EndTime": 1724157438.4296699, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6525491995560495, "count": 1, "min": 0.6525491995560495, "max": 0.6525491995560495}}}
# #metrics {"StartTime": 1724157438.4297066, "EndTime": 1724157438.4297159, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6597345519484135, "count": 1, "min": 0.6597345519484135, "max": 0.6597345519484135}}}
# #metrics {"StartTime": 1724157438.4297528, "EndTime": 1724157438.429763, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.691919000190601, "count": 1, "min": 0.691919000190601, "max": 0.691919000190601}}}
# #metrics {"StartTime": 1724157438.4297936, "EndTime": 1724157438.429802, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6919185303805168, "count": 1, "min": 0.6919185303805168, "max": 0.6919185303805168}}}
# #metrics {"StartTime": 1724157438.429832, "EndTime": 1724157438.4298415, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6919065428616707, "count": 1, "min": 0.6919065428616707, "max": 0.6919065428616707}}}
# #metrics {"StartTime": 1724157438.4298716, "EndTime": 1724157438.4298806, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6919241614090769, "count": 1, "min": 0.6919241614090769, "max": 0.6919241614090769}}}
# #metrics {"StartTime": 1724157438.4299169, "EndTime": 1724157438.4299262, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6966320907860472, "count": 1, "min": 0.6966320907860472, "max": 0.6966320907860472}}}
# #metrics {"StartTime": 1724157438.4299634, "EndTime": 1724157438.4299724, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7024057542232045, "count": 1, "min": 0.7024057542232045, "max": 0.7024057542232045}}}
# #metrics {"StartTime": 1724157438.4300067, "EndTime": 1724157438.430017, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6966032182124623, "count": 1, "min": 0.6966032182124623, "max": 0.6966032182124623}}}
# #metrics {"StartTime": 1724157438.4300525, "EndTime": 1724157438.4300623, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7023286197060032, "count": 1, "min": 0.7023286197060032, "max": 0.7023286197060032}}}
# [08/20/2024 12:37:18 INFO 139985293625152] #quality_metric: host=algo-1, epoch=9, train binary_classification_cross_entropy_objective <loss>=0.5484005737304688
# [08/20/2024 12:37:18 INFO 139985293625152] #early_stopping_criteria_metric: host=algo-1, epoch=9, criteria=binary_classification_cross_entropy_objective, value=0.5483928914655719
# [08/20/2024 12:37:18 INFO 139985293625152] Saving model for epoch: 9
# [08/20/2024 12:37:18 INFO 139985293625152] Saved checkpoint to "/tmp/tmp4ddrnp9z/mx-mod-0000.params"
# [08/20/2024 12:37:18 INFO 139985293625152] Early stop condition met. Stopping training.
# [08/20/2024 12:37:18 INFO 139985293625152] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1724157437.1528542, "EndTime": 1724157438.4365363, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 9, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 63130.0, "count": 1, "min": 63130, "max": 63130}, "Total Batches Seen": {"sum": 639.0, "count": 1, "min": 639, "max": 639}, "Max Records Seen Between Resets": {"sum": 5730.0, "count": 1, "min": 5730, "max": 5730}, "Max Batches Seen Between Resets": {"sum": 58.0, "count": 1, "min": 58, "max": 58}, "Reset Count": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Number of Records Since Last Reset": {"sum": 5730.0, "count": 1, "min": 5730, "max": 5730}, "Number of Batches Since Last Reset": {"sum": 58.0, "count": 1, "min": 58, "max": 58}}}
# [08/20/2024 12:37:18 INFO 139985293625152] #throughput_metric: host=algo-1, train throughput=4463.290885073244 records/second
# [08/20/2024 12:37:18 WARNING 139985293625152] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [08/20/2024 12:37:18 WARNING 139985293625152] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [08/20/2024 12:37:19 INFO 139985293625152] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.5476757187701853)
# [08/20/2024 12:37:19 INFO 139985293625152] #train_score (algo-1) : ('binary_classification_accuracy', 0.7193717277486911)
# [08/20/2024 12:37:19 INFO 139985293625152] #train_score (algo-1) : ('binary_f_1.000', 0.7321785476349101)
# [08/20/2024 12:37:19 INFO 139985293625152] #train_score (algo-1) : ('precision', 0.7297476759628154)
# [08/20/2024 12:37:19 INFO 139985293625152] #train_score (algo-1) : ('recall', 0.7346256684491979)
# [08/20/2024 12:37:19 INFO 139985293625152] #train_score (algo-1) : ('roc_auc_score', 0.7928607037808151)
# [08/20/2024 12:37:19 INFO 139985293625152] #train_score (algo-1) : ('binary_balanced_accuracy', 0.5)
# [08/20/2024 12:37:19 INFO 139985293625152] #train_score (algo-1) : ('binary_log_loss', 0.6617650295674997)
# [08/20/2024 12:37:19 INFO 139985293625152] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.5476757187701853
# [08/20/2024 12:37:19 INFO 139985293625152] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.7193717277486911
# [08/20/2024 12:37:19 INFO 139985293625152] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.7321785476349101
# [08/20/2024 12:37:19 INFO 139985293625152] #quality_metric: host=algo-1, train precision <score>=0.7297476759628154
# [08/20/2024 12:37:19 INFO 139985293625152] #quality_metric: host=algo-1, train recall <score>=0.7346256684491979
# [08/20/2024 12:37:19 INFO 139985293625152] #quality_metric: host=algo-1, train roc_auc_score <score>=0.7928607037808151
# [08/20/2024 12:37:19 INFO 139985293625152] #quality_metric: host=algo-1, train binary_balanced_accuracy <score>=0.5
# [08/20/2024 12:37:19 INFO 139985293625152] #quality_metric: host=algo-1, train binary_log_loss <score>=0.6617650295674997
# [08/20/2024 12:37:19 INFO 139985293625152] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.005, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 0.0001}
# [08/20/2024 12:37:19 INFO 139985293625152] Saved checkpoint to "/tmp/tmp6j9_l9fd/mx-mod-0000.params"
# [08/20/2024 12:37:19 INFO 139985293625152] Test data is not provided.
# #metrics {"StartTime": 1724157424.5368845, "EndTime": 1724157439.049837, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 419.0411567687988, "count": 1, "min": 419.0411567687988, "max": 419.0411567687988}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 5.677700042724609, "count": 10, "min": 0.19097328186035156, "max": 1.0197162628173828}, "update.time": {"sum": 13417.852640151978, "count": 10, "min": 1272.446870803833, "max": 1648.7767696380615}, "finalize.time": {"sum": 608.356237411499, "count": 1, "min": 608.356237411499, "max": 608.356237411499}, "setuptime": {"sum": 2.013683319091797, "count": 1, "min": 2.013683319091797, "max": 2.013683319091797}, "totaltime": {"sum": 14616.783618927002, "count": 1, "min": 14616.783618927002, "max": 14616.783618927002}}}
#
# 2024-08-20 12:37:36 Uploading - Uploading generated training model
# 2024-08-20 12:37:36 Completed - Training job completed
# Training seconds: 160
# Billable seconds: 160

# %%
#Deploying the Trained Model

predictmodel=LogisticModel.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge',
                                   endpoint_name = 'RomeoEEendpoints')
# Out:
# INFO:sagemaker:Creating model with name: Logistic-Demo-v1-2024-08-21-07-37-36-202
# INFO:sagemaker:Creating endpoint-config with name RomeoEEendpoints
# INFO:sagemaker:Creating endpoint with name RomeoEEendpoints
# ----------!
